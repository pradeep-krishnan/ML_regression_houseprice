# %% [markdown]
# # Predicting house price using regression techniques

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import norm, skew, probplot


from sklearn.preprocessing import RobustScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, make_scorer

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
#reading all the files as dataframes
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
sub = pd.read_csv("sample_submission.csv")

# %%
print("shape of train: ", train.shape)
print("shape of test: ",test.shape)
print("shape of submission: ",sub.shape)
# Out:
# shape of train:  (1460, 81)
# shape of test:  (1459, 80)
# shape of submission:  (1459, 2)

# %%
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
test.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0      6    2010        WD         Normal
# 1        Gar2   12500      6    2010        WD         Normal
# 2         NaN       0      3    2010        WD         Normal
# 3         NaN       0      6    2010        WD         Normal
# 4         NaN       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
#Check and drop Id column in train and test
if(train['Id'].nunique() == len(train) and test['Id'].nunique() == len(test)):
    train_id, test_id = train['Id'], test['Id']
    train.drop('Id', axis = 1, inplace = True)
    test.drop('Id', axis = 1, inplace = True)

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Let's get the dependent variable and its descriptive statistics

# %%
for c in train.columns:
    if c not in test.columns:
        print("The dependent variable is %s " %c)

train[c].describe()
# Out:
# The dependent variable is SalePrice
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#Check to see if the target variable follows a normal distribution
sns.distplot(train['SalePrice'], fit = norm)
plt.ylabel('Frequency')
plt.show()

probplot(train['SalePrice'], plot=plt)
plt.show()

# %%
# Log transforming target column to resemble a normal distribution 
train["SalePrice_transformed"] = np.log1p(train["SalePrice"])
sns.distplot(train['SalePrice_transformed'], fit = norm)
plt.ylabel('Frequency')
plt.show()

probplot(train['SalePrice_transformed'], plot=plt)
plt.show()

# %%
#Correlation among values
#Finding correlation
sns.set(style="white")
train_corr = train.corr()

mask = np.zeros_like(train_corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize = (12,12))
cmap = sns.diverging_palette(220, 10, as_cmap = True)

sns.heatmap(train_corr, mask=mask, cmap=cmap, vmax=1, vmin = -1,
            center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %%
for i in range(train.shape[1]):
    if(train.iloc[:,i].dtype == 'int64' or train.iloc[:,i].dtype == 'float64'):
        if(abs(train['SalePrice'].corr(train.iloc[:,i])) >= 0.5 and\
           abs(train['SalePrice'].corr(train.iloc[:,i])) <= 0.9):
                ax = sns.scatterplot(train.iloc[:,i], train['SalePrice'])
                plt.show()

# %%
#Other values that have a high positive correlation are
for i in range(0,len(train_corr)-2):
    for j in range(i+1, len(train_corr)-2):
        if(abs(train_corr.iloc[i,j]) > 0.7):
            ax = sns.scatterplot(train.loc[:, (train_corr.iloc[:,i].name)], \
                                 train.loc[:, (train_corr.iloc[:,j].name)])
            plt.show()

# %%
#Histogram plots
hist_columns = ['SalePrice','LotArea', 'YearBuilt','YearRemodAdd','GrLivArea',\
       'TotRmsAbvGrd', 'MoSold']
for col in hist_columns:
    print("Histogram of "+str(train[col].name)+":")
    sns.distplot(train[col], kde = False)
    plt.show()
# Out:
# Histogram of SalePrice:
# Histogram of LotArea:
# Histogram of YearBuilt:
# Histogram of YearRemodAdd:
# Histogram of GrLivArea:
# Histogram of TotRmsAbvGrd:
# Histogram of MoSold:

# %%
count_box_col = ['HouseStyle', 'Foundation','GarageType','SaleCondition',\
                     'OverallQual', 'OverallCond', 'BedroomAbvGr','FullBath',\
                     'BsmtFullBath', 'Fireplaces', 'GarageCars', 'YrSold']

for col in count_box_col:
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    ax1 = sns.countplot(train[col], ax = ax1)
    ax2 = sns.boxplot(train[col], train['SalePrice'], ax=ax2)

# %%
#Basement features
pie_cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']

for col in pie_cols:
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    ax1=sns.boxplot(train[col], train['SalePrice'], ax=ax1)
    sample_df = pd.DataFrame(train[col].value_counts()).reset_index()
    sample_df.columns = [col, 'number']
    #fig, ax2 = plt.subplots(figsize=(5,5))
    print("Boxplot and Pie chart of "+col+":")
    ax2.pie(sample_df['number'], labels=sample_df[col],\
       autopct='%1.1f%%', startangle = 90)
    ax2.axis('equal')  
    plt.tight_layout()
    plt.show()
# Out:
# Boxplot and Pie chart of BsmtQual:
# Boxplot and Pie chart of BsmtCond:
# Boxplot and Pie chart of BsmtExposure:
# Boxplot and Pie chart of BsmtFinType1:
# Boxplot and Pie chart of BsmtFinType2:

# %%
train[((train['YrSold'] - train['YearRemodAdd']) < 0)][['YrSold','YearRemodAdd' ]]
# Out:
#      YrSold  YearRemodAdd
# 523    2007          2008

# %%
#YearRemod cannot be after YrSold
train.loc[((train['YrSold'] - train['YearRemodAdd']) < 0), 'YearRemodAdd'] = 2007

# %% [markdown]
# ### Handling missing values

# %%
#Combining train and test 
y_SalePrice = train['SalePrice']
y_train = train['SalePrice_transformed'] 
train.drop(['SalePrice', 'SalePrice_transformed'], axis = 1, inplace = True)
df = train.copy()
df = df.append(test).reset_index(drop = True)

# %%
#Get datatypes of columns
print("Datatypes of columns: ")
print(df.dtypes.value_counts())
# Out:
# Datatypes of columns:
# object     43
# int64      25
# float64    11
# dtype: int64

# %%
obj_col = df.select_dtypes(include = ['object'])
float_col = df.select_dtypes(exclude = ['object'])

# %%
#Handling skew in independent columns using log transform
skew_table = float_col.skew().sort_values(ascending = False).reset_index()
skew_table.columns = ['feature', 'skew']
skewed_features = skew_table[skew_table['skew'] > 0.5].feature.tolist()
for c in skewed_features:
    df[c] = np.log1p(df[c])

# %%
print('\nNumber of columns with missing values is {}'.\
      format(sum(df.isnull().sum(axis=0) != 0)))
# Out:
# Number of columns with missing values is 34

# %%
plt.figure(figsize=(8,12))
missing_df = df.isnull().sum(axis=0).sort_values(ascending=False).reset_index().head(20)
missing_df.columns = ['Feature', 'Number of missing values']
ax = sns.barplot(x="Number of missing values", y="Feature", data=missing_df)

# %%
#Fill object column missing values by None and other columns by mean
for col in df.columns:
    if(df[col].isnull().sum() != 0):
        if(df[col].dtype == 'object'):
            df[col].fillna('None', inplace = True)
        else:
            df[col].fillna(df[col].mean(), inplace = True)

# %%
#Building Age when sold
df['Age'] = df['YrSold'] - df['YearBuilt']

#Years since remod
df['Yearsinceremod'] = df['YrSold'] - df['YearRemodAdd']

# %%
df = pd.get_dummies(df)

# %%
train = df.iloc[:len(train),:]
test = df.iloc[len(train):,:]

# %%
from sklearn.preprocessing import RobustScaler
rscaler = RobustScaler()
x_train = rscaler.fit_transform(train)
x_test = rscaler.transform(test)

# %% [markdown]
# ### Regression Machine Learning models

# %%
def rmsle_cv(model):
    rmsle= np.sqrt(-cross_val_score(model, x_train, y_train, scoring="neg_mean_squared_error", cv = 5))
    return(rmsle)

# %% [markdown]
# #### Lasso regression

# %%
model_lasso = LassoCV(alphas = [0.001, 0.005, 0.01,0.05, 0.1,0.3, 0.5,1,2]).fit(x_train, y_train)
rmsle_cv(model_lasso).min()
# Out:
# 0.10506184825956476

# %%
model_lasso.alpha_
# Out:
# 0.001

# %%
model_lasso = LassoCV(alphas = [0.001]).fit(x_train, y_train)

# %%
feat = pd.Series(model_lasso.coef_, index = train.columns)
print("Lasso picked " + str(sum(feat != 0)) + " features")
print (str(sum(feat == 0)) + " features were removed")
# Out:
# Lasso picked 76 features
# 236 features were removed

# %%
plt.figure(figsize=(6,10))
features = pd.concat([feat.sort_values().head(5), feat.sort_values().tail(5)])
features.plot(kind = "barh")
plt.title("Lasso coefficients")
plt.show()

# %%
residual_df = pd.DataFrame({'y_pred': model_lasso.predict(train), 'y_true':y_train})
residual_df.plot(x = 'y_pred', y = 'y_true', kind = 'scatter')
plt.show()

residual_df['residuals'] = residual_df['y_true'] - residual_df['y_pred'] 
residual_df.plot(x = 'y_true', y = 'residuals', kind = 'scatter')
plt.show()

# %%
score = rmsle_cv(model_lasso)
score.mean()
# Out:
# 0.12343601899083059

# %%
lasso_pred = np.expm1(model_lasso.predict(x_test))
lasso_pred
# Out:
# array([116323.00798757, 151349.75589832, 180110.99736064, ...,
#        170094.98945187, 119014.68904677, 232162.11526053])

# %% [markdown]
# #### Ridge regression

# %%
alphas = [0.01, 0.1, 0.3, 0.5, 1, 5, 15, 30, 50, 100]
cv_ridge = [rmsle_cv(Ridge(alpha = alpha)).mean() 
            for alpha in alphas]

# %%
cv_ridge = pd.Series(cv_ridge, index = alphas)
cv_ridge.plot(title = "Ridge regression")
plt.xlabel("alpha")
plt.ylabel("error")
plt.show()
cv_ridge.min()
# Out:
# 0.12637962791549145

# %%
ridge_alpha = cv_ridge.min()
model_ridge = RidgeCV(alphas = [ridge_alpha]).fit(x_train, y_train)
ridge_pred = np.expm1(model_ridge.predict(x_test))
ridge_pred
# Out:
# array([121420.04708259, 161956.84127351, 188771.05364643, ...,
#        176700.15053783, 121410.00872585, 218676.69760013])

# %% [markdown]
# #### Decision Tree

# %%
decisiontree = DecisionTreeRegressor(max_depth = 6)
model_dt = decisiontree.fit(x_train, y_train)
rmsle_cv(model_dt).min()
# Out:
# 0.17970106790711526

# %%
model_dt.get_params
# Out:
# <bound method BaseEstimator.get_params of DecisionTreeRegressor(criterion='mse', max_depth=6, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')>

# %%
dt_pred = np.expm1(model_dt.predict(x_test))
dt_pred
# Out:
# array([130756.1619786 , 150624.81163363, 187937.45597093, ...,
#        150624.81163363, 130756.1619786 , 232409.53082656])

# %%
from sklearn.externals.six import StringIO  
import pydotplus
from sklearn.tree import export_graphviz
from IPython.display import Image

# %%
dot_data = StringIO()
export_graphviz(model_dt, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
#Can doubleclick to zoom
Image(graph.create_png())
